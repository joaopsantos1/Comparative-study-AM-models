# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.preprocessing import StandardScaler

from codecarbon import EmissionsTracker

# %%
df = pd.read_csv('data/all_data.csv', sep=',', encoding='latin-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414829 entries, 0 to 414828
# Data columns (total 18 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       414829 non-null  float64
#  1   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  414829 non-null  float64
#  2   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        414829 non-null  float64
#  3   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       414829 non-null  float64
#  4   RADIACAO GLOBAL (Kj/m²)                                414829 non-null  float64
#  5   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           414829 non-null  float64
#  6   TEMPERATURA DO PONTO DE ORVALHO (°C)                   414829 non-null  float64
#  7   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             414829 non-null  float64
#  8   TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             414829 non-null  float64
#  9   TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       414829 non-null  float64
#  10  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       414829 non-null  float64
#  11  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               414829 non-null  float64
#  12  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               414829 non-null  float64
#  13  UMIDADE RELATIVA DO AR, HORARIA (%)                    414829 non-null  float64
#  14  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   414829 non-null  float64
#  15  VENTO, RAJADA MAXIMA (m/s)                             414829 non-null  float64
#  16  VENTO, VELOCIDADE HORARIA (m/s)                        414829 non-null  float64
#  17  datetime                                               414829 non-null  object
# dtypes: float64(17), object(1)
# memory usage: 57.0+ MB

# %%
X_prec = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_prec = df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
X_temp = df[[
       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_temp = df[['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']]

# %%
X_umid = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (Kj/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_umid = df[['UMIDADE RELATIVA DO AR, HORARIA (%)']]

# %%
def split_train_test(X, y, train_size):
    X_train, X_test = X[:round(X.shape[0]*train_size)], X[round(X.shape[0]*train_size):]
    y_train, y_test = y[:round(y.shape[0]*train_size)], y[round(y.shape[0]*train_size):]

    return X_train, X_test, y_train, y_test

def plot_prediction_over_time(y_test, predictions, timestamps, start_date=None, end_date=None, save=False):
    timestamps = pd.to_datetime(timestamps)

    data = pd.DataFrame({
        'Timestamp': timestamps,
        'Actual': y_test,
        'Predicted': predictions
    })

    if start_date:
        data = data[data['Timestamp'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['Timestamp'] <= pd.to_datetime(end_date)]

    plt.figure(figsize=(12, 6))
    plt.plot(data['Timestamp'], data['Actual'], label='Actual Values', color='blue', linewidth=2)
    plt.plot(data['Timestamp'], data['Predicted'], label='Predicted Values', color='orange', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title('Actual vs. Predicted Values Over Time')
    plt.legend()
    plt.grid(True)

    
    if save: 
        plt.savefig(save)
        
    plt.show()


def plot_real_vs_predicted(y_test, predictions, save=False):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, predictions, alpha=0.7, color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--', color='red', linewidth=2, label="Ideal Fit")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title("Real vs Predicted Values")
    plt.legend()
    plt.grid(True)

    if save: 
        plt.savefig(save)
    
    plt.show()

# %% [markdown]
# ## mlp temperature

# %%
X_temp_train, X_temp_test, y_temp_train, y_temp_test = split_train_test(X_temp, y_temp, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_temp.shape[1], activation='relu', input_shape=(X_temp.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\janse\Playground\final_project_AM\extreme-waether-forecasting\.venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp TEMPERATURE train",
    output_file='./codecarbon-mlp/codecarbon_emissions_temp.csv',
    log_level = "critical"
)

tracker.start()


model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error'] 
)

model.summary()

model.fit(X_temp_train, y_temp_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_temp_test, y_temp_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# [codecarbon WARNING @ 21:53:46] Multiple instances of codecarbon are allowed to run at the same time.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549 (2.14 KB)
#  Trainable params: 549 (2.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 9s 782us/step - loss: 3073.0088 - mean_absolute_error: 15.8984
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 786us/step - loss: 243.5933 - mean_absolute_error: 5.2981
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 743us/step - loss: 175.8049 - mean_absolute_error: 4.4321
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 743us/step - loss: 141.2451 - mean_absolute_error: 4.1212
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 736us/step - loss: 130.5872 - mean_absolute_error: 3.9520
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 753us/step - loss: 102.3714 - mean_absolute_error: 3.7232
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 739us/step - loss: 99.5528 - mean_absolute_error: 3.6772
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 742us/step - loss: 90.2582 - mean_absolute_error: 3.5226
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 807us/step - loss: 89.9363 - mean_absolute_error: 3.4785
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 780us/step - loss: 85.8884 - mean_absolute_error: 3.3746
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - loss: 79.1953 - mean_absolute_error: 3.3330
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 756us/step - loss: 71.0502 - mean_absolute_error: 3.2719
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - loss: 70.4999 - mean_absolute_error: 3.2088
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 760us/step - loss: 69.1389 - mean_absolute_error: 3.2285
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - loss: 77.9786 - mean_absolute_error: 3.2702
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 760us/step - loss: 71.5675 - mean_absolute_error: 3.1594
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 757us/step - loss: 71.0934 - mean_absolute_error: 3.1585
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 766us/step - loss: 67.9452 - mean_absolute_error: 3.1424
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - loss: 67.2884 - mean_absolute_error: 3.1240
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 767us/step - loss: 62.3523 - mean_absolute_error: 3.0843
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - loss: 65.2814 - mean_absolute_error: 3.0882
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 771us/step - loss: 68.0639 - mean_absolute_error: 3.0995
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - loss: 62.6176 - mean_absolute_error: 3.0503
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 774us/step - loss: 61.7306 - mean_absolute_error: 3.0552
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 759us/step - loss: 57.1587 - mean_absolute_error: 2.9917
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 751us/step - loss: 60.3233 - mean_absolute_error: 3.0294
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 758us/step - loss: 64.6505 - mean_absolute_error: 3.0197
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 759us/step - loss: 56.8716 - mean_absolute_error: 2.9725
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 762us/step - loss: 64.5127 - mean_absolute_error: 3.0450
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 772us/step - loss: 57.5017 - mean_absolute_error: 2.9687
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 772us/step - loss: 57.1153 - mean_absolute_error: 2.9815
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 762us/step - loss: 81.1068 - mean_absolute_error: 3.0565
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 763us/step - loss: 69.1137 - mean_absolute_error: 3.0299
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 764us/step - loss: 63.6868 - mean_absolute_error: 2.9741
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 768us/step - loss: 53.0805 - mean_absolute_error: 2.9263
# Epoch 36/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 772us/step - loss: 59.3179 - mean_absolute_error: 2.9246
# Epoch 37/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 765us/step - loss: 59.9640 - mean_absolute_error: 2.9352
# Epoch 38/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━
100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 790us/step - loss: 50.6764 - mean_absolute_error: 2.8100
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - loss: 55.8501 - mean_absolute_error: 2.8385
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 50.9008 - mean_absolute_error: 2.7881
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 779us/step - loss: 47.4345 - mean_absolute_error: 2.7910
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 785us/step - loss: 46.1944 - mean_absolute_error: 2.7817
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 796us/step - loss: 52.4172 - mean_absolute_error: 2.8087
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 786us/step - loss: 54.8220 - mean_absolute_error: 2.8198
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 795us/step - loss: 51.1232 - mean_absolute_error: 2.7956
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 786us/step - loss: 53.4758 - mean_absolute_error: 2.8047
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - loss: 55.2322 - mean_absolute_error: 2.8231
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 785us/step - loss: 52.6243 - mean_absolute_error: 2.8101
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 792us/step - loss: 52.0207 - mean_absolute_error: 2.8038
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 796us/step - loss: 48.6796 - mean_absolute_error: 2.8000
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 790us/step - loss: 55.7869 - mean_absolute_error: 2.8487
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 46.4641 - mean_absolute_error: 2.7889
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 791us/step - loss: 54.3775 - mean_absolute_error: 2.8209
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 793us/step - loss: 49.1757 - mean_absolute_error: 2.7709
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 789us/step - loss: 44.9144 - mean_absolute_error: 2.7654
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - loss: 43.5840 - mean_absolute_error: 2.7744
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 52.2178 - mean_absolute_error: 2.8100
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 792us/step - loss: 55.7568 - mean_absolute_error: 2.8105
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 786us/step - loss: 48.7658 - mean_absolute_error: 2.7934
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - loss: 41.7179 - mean_absolute_error: 2.7457
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 796us/step - loss: 57.2077 - mean_absolute_error: 2.8390
# 2593/2593 - 2s - 636us/step - loss: 11333.0801 - mean_absolute_error: 36.7781
# Loss (MSE): 11333.080078125
# Mean Absolute Error: 36.778076171875
# Root Mean Squared Error (RMSE): 106.45694001860565
# emissions=0.001339137946836338

# %%
y_temp_pred_probs = model.predict(X_temp_test, verbose=2)
# Out:
# 2593/2593 - 1s - 391us/step

# %%
y_temp_test_flat = y_temp_test.values.flatten()
y_temp_pred_flat = y_temp_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_temp_test_flat, y_temp_pred_flat, save='./plots/mlp_temp_real_x_pred.png')

# %%
start_date = "2025-01-01 01:00:00"
end_date = "2025-05-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_temp_test_flat, y_temp_pred_flat, timestamps_test, start_date, end_date, save='plots/mlp_temp_over_time.png')

# %% [markdown]
# ## mlp precipitation

# %%
X_prec_train, X_prec_test, y_prec_train, y_prec_test = split_train_test(X_prec, y_prec, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_prec.shape[1], activation='relu', input_shape=(X_prec.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\janse\Playground\final_project_AM\extreme-waether-forecasting\.venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp PRECIPITATION train",
    output_file='./codecarbon-mlp/codecarbon_emissions_prec.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_prec_train, y_prec_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_prec_test, y_prec_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849 (3.32 KB)
#  Trainable params: 849 (3.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 737us/step - loss: 8759.9248 - mean_absolute_error: 7.0890
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 716us/step - loss: 28.2594 - mean_absolute_error: 0.5804
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 705us/step - loss: 5.0745 - mean_absolute_error: 0.3068
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 714us/step - loss: 1.2305 - mean_absolute_error: 0.2377
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 718us/step - loss: 1.1711 - mean_absolute_error: 0.2361
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 713us/step - loss: 1.1349 - mean_absolute_error: 0.2329
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 718us/step - loss: 1.2003 - mean_absolute_error: 0.2361
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 733us/step - loss: 1.2649 - mean_absolute_error: 0.2436
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 710us/step - loss: 1.1654 - mean_absolute_error: 0.2339
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 712us/step - loss: 1.1434 - mean_absolute_error: 0.2348
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 719us/step - loss: 1.0692 - mean_absolute_error: 0.2308
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 713us/step - loss: 1.1500 - mean_absolute_error: 0.2327
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 716us/step - loss: 1.0997 - mean_absolute_error: 0.2333
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 715us/step - loss: 1.1366 - mean_absolute_error: 0.2351
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 717us/step - loss: 1.2384 - mean_absolute_error: 0.2342
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 722us/step - loss: 1.0540 - mean_absolute_error: 0.2299
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 718us/step - loss: 1.1880 - mean_absolute_error: 0.2374
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 720us/step - loss: 1.1023 - mean_absolute_error: 0.2337
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 724us/step - loss: 1.2248 - mean_absolute_error: 0.2400
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 740us/step - loss: 1.2317 - mean_absolute_error: 0.2401
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step - loss: 1.2580 - mean_absolute_error: 0.2347
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 9s 839us/step - loss: 1.1883 - mean_absolute_error: 0.2398
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 782us/step - loss: 1.0926 - mean_absolute_error: 0.2341
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 778us/step - loss: 1.2822 - mean_absolute_error: 0.2385
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 784us/step - loss: 1.2554 - mean_absolute_error: 0.2415
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 768us/step - loss: 1.1692 - mean_absolute_error: 0.2337
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 785us/step - loss: 1.0997 - mean_absolute_error: 0.2321
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 810us/step - loss: 1.1785 - mean_absolute_error: 0.2364
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 794us/step - loss: 1.1234 - mean_absolute_error: 0.2364
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 780us/step - loss: 1.2521 - mean_absolute_error: 0.2413
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 789us/step - loss: 1.2037 - mean_absolute_error: 0.2361
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 773us/step - loss: 1.0593 - mean_absolute_error: 0.2304
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - loss: 1.2096 - mean_absolute_error: 0.2367
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 794us/step - loss: 1.3469 - mean_absolute_error: 0.2445
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 796us/step - loss: 1.1488 - mean_absolute_error: 0.2325
# Epoch 36/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - loss: 1.1075 - mean_absolute_error: 0.2364
# Epoch 37/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 790us/step - loss: 1.0953 - mean_absolute_error: 0.2331
# Epoch 38/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 782us/step - loss: 1.1198 - mean_absolute_error: 0.2330
# Epoch 39/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 777us/step - loss: 1.1028 - mean_absolute_error: 0.2331
# Epoch 40/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 776us/step - loss: 1.2011 - mean_absolute_error: 0.2393
# Epoch 41/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 777us/step - loss: 1.1915 - mean_absolute_error: 0.2383
# Epoch 42/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 779us/step - loss: 1.1555 - mean_absolute_error: 0.2326
# Epoch 43/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.2039 - mean_absolute_error: 0.2376
# Epoch 44/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 792us/step - loss: 1.3138 - mean_absolute_error: 0.2398
# Epoch 45/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 798us/step - loss: 1.1745 - mean_absolute_error: 0.2362
# Epoch 46/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 785us/step - loss: 1.2704 - mean_absolute_error: 0.2396
# Epoch 47/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 791us/step - loss: 1.2890 - mean_absolute_error: 0.2356
# Epoch 48/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 790us/step - loss: 1.1743 - mean_absolute_error: 0.2375
# Epoch 49/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 805us/step - loss: 1.1653 - mean_absolute_error: 0.2360
# Epoch 50/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 9s 817us/step - loss: 1.1663 - mean_absolute_error: 0.2344
# Epoch 51/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 776us/step - loss: 1.1223 - mean_absolute_error: 0.2300
# Epoch 52/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 775us/step - loss: 1.1855 - mean_absolute_error: 0.2404
# Epoch 53/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 785us/step - loss: 1.1562 - mean_absolute_error: 0.2333
# Epoch 54/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 772us/step - loss: 1.1773 - mean_absolute_error: 0.2373
# Epoch 55/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 781us/step - loss: 1.2285 - mean_absolute_error: 0.2359
# Epoch 56/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 784us/step - loss: 1.0757 - mean_absolute_error: 0.2346
# Epoch 57/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - loss: 1.1444 - mean_absolute_error: 0.2324
# Epoch 58/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.2478 - mean_absolute_error: 0.2393
# Epoch 59/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 787us/step - loss: 1.2873 - mean_absolute_error: 0.2436
# Epoch 60/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 780us/step - loss: 1.1327 - mean_absolute_error: 0.2333
# Epoch 61/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 783us/step - loss: 1.1366 - mean_absolute_error: 0.2351
# Epoch 62/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 777us/step - loss: 1.1830 - mean_absolute_error: 0.2339
# Epoch 63/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 782us/step - loss: 1.0638 - mean_absolute_error: 0.2329
# Epoch 64/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.1696 - mean_absolute_error: 0.2352
# Epoch 65/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 799us/step - loss: 1.1396 - mean_absolute_error: 0.2367
# Epoch 66/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 781us/step - loss: 1.1282 - mean_absolute_error: 0.2331
# Epoch 67/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 784us/step - loss: 1.1528 - mean_absolute_error: 0.2374
# Epoch 68/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 802us/step - loss: 1.1362 - mean_absolute_error: 0.2374
# Epoch 69/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.1903 - mean_absolute_error: 0.2373
# Epoch 70/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 791us/step - loss: 1.2220 - mean_absolute_error: 0.2415
# Epoch 71/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 810us/step - loss: 1.1918 - mean_absolute_error: 0.2356
# Epoch 72/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 777us/step - loss: 1.2097 - mean_absolute_error: 0.2347
# Epoch 73/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 794us/step - loss: 1.1084 - mean_absolute_error: 0.2328
# Epoch 74/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 786us/step - loss: 1.1941 - mean_absolute_error: 0.2352
# Epoch 75/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 791us/step - loss: 1.1986 - mean_absolute_error: 0.2363
# Epoch 76/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 790us/step - loss: 1.1552 - mean_absolute_error: 0.2320
# Epoch 77/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 788us/step - loss: 1.1792 - mean_absolute_error: 0.2352
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 9s 830us/step - loss: 1.1145 - mean_absolute_error: 0.2333
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 800us/step - loss: 1.1433 - mean_absolute_error: 0.2366
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 806us/step - loss: 1.1681 - mean_absolute_error: 0.2387
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 800us/step - loss: 1.2293 - mean_absolute_error: 0.2379
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 813us/step - loss: 1.1283 - mean_absolute_error: 0.2319
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 793us/step - loss: 1.1721 - mean_absolute_error: 0.2350
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 799us/step - loss: 1.1853 - mean_absolute_error: 0.2369
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 811us/step - loss: 1.1964 - mean_absolute_error: 0.2416
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.1766 - mean_absolute_error: 0.2370
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 804us/step - loss: 1.1356 - mean_absolute_error: 0.2317
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 794us/step - loss: 1.2040 - mean_absolute_error: 0.2353
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 9s 824us/step - loss: 1.1698 - mean_absolute_error: 0.2357
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 813us/step - loss: 1.0526 - mean_absolute_error: 0.2302
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 11s 855us/step - loss: 1.1453 - mean_absolute_error: 0.2342
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 814us/step - loss: 1.1610 - mean_absolute_error: 0.2315
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 798us/step - loss: 1.1586 - mean_absolute_error: 0.2345
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 814us/step - loss: 1.2071 - mean_absolute_error: 0.2362
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 802us/step - loss: 1.1289 - mean_absolute_error: 0.2314
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 799us/step - loss: 1.1812 - mean_absolute_error: 0.2387
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 10s 818us/step - loss: 1.1078 - mean_absolute_error: 0.2330
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 813us/step - loss: 1.2640 - mean_absolute_error: 0.2357
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 798us/step - loss: 1.1926 - mean_absolute_error: 0.2382
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 795us/step - loss: 1.2756 - mean_absolute_error: 0.2428
# 2593/2593 - 2s - 655us/step - loss: 18212.8691 - mean_absolute_error: 36.2421
# Loss (MSE): 18212.869140625
# Mean Absolute Error: 36.2420539855957
# Root Mean Squared Error (RMSE): 134.95506341232624
# emissions=0.0013490335223428696

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 134.95506341232624

# %%
y_prec_pred_probs = model.predict(X_prec_test, verbose=2)
# Out:
# 2593/2593 - 1s - 400us/step

# %%
y_prec_test_flat = y_prec_test.values.flatten()
y_prec_pred_flat = y_prec_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_prec_test_flat, y_prec_pred_flat, save='plots/mlp_prec_real_x_pred.png')

# %%
start_date = "2025-01-01 01:00:00"
end_date = "2025-05-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save='plots/mlp_prec_over_time.png')

# %% [markdown]
# ## mlp umidade

# %%
X_umid_train, X_umid_test, y_umid_train, y_umid_test = split_train_test(X_umid, y_umid, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_umid.shape[1], activation='relu', input_shape=(X_umid.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# c:\Users\janse\Playground\final_project_AM\extreme-waether-forecasting\.venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tracker = EmissionsTracker(
    project_name="mlp UMIDADE train",
    output_file='./codecarbon-mlp/codecarbon_emissions_umid.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_umid_train, y_umid_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_umid_test, y_umid_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 13)             │           182 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 663 (2.59 KB)
#  Trainable params: 663 (2.59 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 751us/step - loss: 16919.7109 - mean_absolute_error: 29.4707
# Epoch 2/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 729us/step - loss: 1514.7222 - mean_absolute_error: 15.1515
# Epoch 3/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 714us/step - loss: 1095.9974 - mean_absolute_error: 11.4244
# Epoch 4/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 709us/step - loss: 899.1017 - mean_absolute_error: 9.6097
# Epoch 5/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 730us/step - loss: 815.9672 - mean_absolute_error: 8.8305
# Epoch 6/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 726us/step - loss: 748.3115 - mean_absolute_error: 8.3031
# Epoch 7/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 740us/step - loss: 694.1578 - mean_absolute_error: 7.9478
# Epoch 8/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 723us/step - loss: 669.5975 - mean_absolute_error: 7.7063
# Epoch 9/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 728us/step - loss: 659.9163 - mean_absolute_error: 7.4890
# Epoch 10/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 712us/step - loss: 640.0840 - mean_absolute_error: 7.3674
# Epoch 11/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 719us/step - loss: 669.3463 - mean_absolute_error: 7.5618
# Epoch 12/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 725us/step - loss: 638.6709 - mean_absolute_error: 7.3778
# Epoch 13/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 723us/step - loss: 587.9301 - mean_absolute_error: 7.1401
# Epoch 14/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 723us/step - loss: 608.3218 - mean_absolute_error: 7.2265
# Epoch 15/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 733us/step - loss: 556.2182 - mean_absolute_error: 7.0299
# Epoch 16/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 718us/step - loss: 584.8850 - mean_absolute_error: 6.8583
# Epoch 17/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 721us/step - loss: 571.3315 - mean_absolute_error: 6.7988
# Epoch 18/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 715us/step - loss: 551.1160 - mean_absolute_error: 6.7649
# Epoch 19/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 718us/step - loss: 548.1558 - mean_absolute_error: 6.7495
# Epoch 20/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 764us/step - loss: 532.5662 - mean_absolute_error: 6.6301
# Epoch 21/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 726us/step - loss: 499.1418 - mean_absolute_error: 6.5442
# Epoch 22/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 723us/step - loss: 562.9478 - mean_absolute_error: 6.7074
# Epoch 23/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 719us/step - loss: 554.9293 - mean_absolute_error: 6.7188
# Epoch 24/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 724us/step - loss: 541.6700 - mean_absolute_error: 6.5414
# Epoch 25/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 719us/step - loss: 530.9601 - mean_absolute_error: 6.4295
# Epoch 26/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 734us/step - loss: 571.9758 - mean_absolute_error: 6.4685
# Epoch 27/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 721us/step - loss: 537.8353 - mean_absolute_error: 6.4162
# Epoch 28/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 736us/step - loss: 519.9429 - mean_absolute_error: 6.4116
# Epoch 29/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 723us/step - loss: 515.8389 - mean_absolute_error: 6.3869
# Epoch 30/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 733us/step - loss: 481.1445 - mean_absolute_error: 6.0984
# Epoch 31/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 7s 716us/step - loss: 523.6206 - mean_absolute_error: 6.2304
# Epoch 32/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 730us/step - loss: 527.2366 - mean_absolute_error: 6.1880
# Epoch 33/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 727us/step - loss: 490.1325 - mean_absolute_error: 6.0625
# Epoch 34/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 728us/step - loss: 467.6094 - mean_absolute_error: 5.9976
# Epoch 35/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s
100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 740us/step - loss: 416.9763 - mean_absolute_error: 5.5123
# Epoch 75/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 737us/step - loss: 424.5376 - mean_absolute_error: 5.5929
# Epoch 76/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 750us/step - loss: 461.3044 - mean_absolute_error: 5.5372
# Epoch 77/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 748us/step - loss: 411.4728 - mean_absolute_error: 5.4468
# Epoch 78/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 751us/step - loss: 440.6989 - mean_absolute_error: 5.6522
# Epoch 79/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 745us/step - loss: 447.9029 - mean_absolute_error: 5.5772
# Epoch 80/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 766us/step - loss: 428.6790 - mean_absolute_error: 5.5798
# Epoch 81/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 747us/step - loss: 432.5853 - mean_absolute_error: 5.4638
# Epoch 82/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 751us/step - loss: 409.9243 - mean_absolute_error: 5.4527
# Epoch 83/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 745us/step - loss: 423.4903 - mean_absolute_error: 5.5496
# Epoch 84/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 744us/step - loss: 389.2507 - mean_absolute_error: 5.3896
# Epoch 85/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - loss: 395.6631 - mean_absolute_error: 5.3426
# Epoch 86/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 744us/step - loss: 393.9166 - mean_absolute_error: 5.4761
# Epoch 87/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 756us/step - loss: 430.8087 - mean_absolute_error: 5.5834
# Epoch 88/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 745us/step - loss: 422.5565 - mean_absolute_error: 5.4880
# Epoch 89/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - loss: 446.2547 - mean_absolute_error: 5.5906
# Epoch 90/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 758us/step - loss: 396.1101 - mean_absolute_error: 5.3109
# Epoch 91/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 751us/step - loss: 419.1317 - mean_absolute_error: 5.4306
# Epoch 92/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 750us/step - loss: 426.1637 - mean_absolute_error: 5.4570
# Epoch 93/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 752us/step - loss: 425.8615 - mean_absolute_error: 5.4366
# Epoch 94/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 754us/step - loss: 413.4877 - mean_absolute_error: 5.4536
# Epoch 95/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 738us/step - loss: 386.4192 - mean_absolute_error: 5.2840
# Epoch 96/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 748us/step - loss: 399.6916 - mean_absolute_error: 5.3404
# Epoch 97/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 754us/step - loss: 413.8755 - mean_absolute_error: 5.3487
# Epoch 98/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 749us/step - loss: 402.7248 - mean_absolute_error: 5.3595
# Epoch 99/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 753us/step - loss: 456.0257 - mean_absolute_error: 5.8186
# Epoch 100/100
# 10371/10371 ━━━━━━━━━━━━━━━━━━━━ 8s 757us/step - loss: 371.5828 - mean_absolute_error: 5.2238
# 2593/2593 - 2s - 627us/step - loss: 18746980.0000 - mean_absolute_error: 1244.5278
# Loss (MSE): 18746980.0
# Mean Absolute Error: 1244.52783203125
# Root Mean Squared Error (RMSE): 4329.778285316697
# emissions=0.001214472191138085

# %%
rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 4329.778285316697

# %%
y_umid_pred_probs = model.predict(X_umid_test, verbose=2)
# Out:
# 2593/2593 - 1s - 382us/step

# %%
y_umid_test_flat = y_umid_test.values.flatten()
y_umid_pred_flat = y_umid_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_umid_test_flat, y_umid_pred_flat, save='plots/mlp_umid_real_x_pred.png')

# %%
start_date = "2025-01-01 01:00:00"
end_date = "2025-05-31 23:00:00"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["datetime"]

plot_prediction_over_time(y_umid_test_flat, y_umid_pred_flat, timestamps_test, start_date, end_date,  save='plots/mlp_umid_over_time.png')
